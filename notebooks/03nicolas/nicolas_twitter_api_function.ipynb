# %% [markdown]
# # **API**

# %%
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time

# %%
import os
from dotenv import load_dotenv
from os.path import join, dirname

# %%
def create_url(keyword, start_date, end_date, max_results = 10):
    
    search_url = "https://api.twitter.com/2/tweets/search/all" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': max_results,
                    'expansions': 'author_id,geo.place_id',
                    'tweet.fields': 'id,text,created_at,lang,public_metrics,source',
                    'user.fields': 'id,created_at,location,public_metrics',
                    'place.fields': 'full_name,country_code,geo,place_type',
                    'next_token': {}}
    return (search_url, query_params)

# %%
def connect_to_endpoint(url, headers, params, next_token):
    
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
        return None
    return response.json()

# %%
query = """(@cducsubt OR @CDU OR @ArminLaschet  OR #Laschet OR #ArminLaschet  OR #arminlaschet OR #laschet OR #cdu OR #CDU OR CDU/CSU OR Laschet)
lang:de -is:retweet
-#GRUENEN -@Die_Gruenen -Baerbock -@ABaerbock
-#SPD -@spdde -Scholz -@OlafScholz
-#AFD -@AfD -Weidel -@Alice_Weidel -Chrupalla -@Tino_Chrupalla
-#FDP -@fdp -Lindner -@c_lindner
-#DieLinke -@dieLinke -Wissler -@Janine_Wissler -Bartsch -@DietmarBartsch
-#FreieWaehler -@FREIEWAEHLER_BV
-#diePARTEI -@DiePARTEI
-@Tierschutzparte -NPD -@Piratenpartei -#Piraten -#dieBasis -@diebasispartei -#Volt -@VoltDeutschland"""

# %%
response = requests.request("GET", url[0], headers = headers, params = url[1])
print("Endpoint Response Code: " + str(response.status_code))
# Out:
# Endpoint Response Code: 200

# %%
response.headers
# Out:
# {'date': 'Tue, 31 Aug 2021 14:02:52 UTC', 'server': 'tsa_o', 'set-cookie': 'personalization_id="v1_7i96wC6DqMB/MzWhv6pnUQ=="; Max-Age=63072000; Expires=Thu, 31 Aug 2023 14:02:52 GMT; Path=/; Domain=.twitter.com; Secure; SameSite=None, guest_id=v1%3A163041857216519229; Max-Age=63072000; Expires=Thu, 31 Aug 2023 14:02:52 GMT; Path=/; Domain=.twitter.com; Secure; SameSite=None', 'content-type': 'application/json; charset=utf-8', 'cache-control': 'no-cache, no-store, max-age=0', 'content-length': '1594', 'x-access-level': 'read', 'x-frame-options': 'SAMEORIGIN', 'content-encoding': 'gzip', 'x-xss-protection': '0', 'x-rate-limit-limit': '300', 'x-rate-limit-reset': '1630418778', 'content-disposition': 'attachment; filename=json.json', 'x-content-type-options': 'nosniff', 'x-rate-limit-remaining': '288', 'strict-transport-security': 'max-age=631138519', 'x-connection-hash': '39f308a9eaa1d2b532cc14dfd2ea80a890a5473589580d1456b8964ca9492ca9'}

# %%
url = create_url(keyword, start_time,end_time, max_results)
response = connect_to_endpoint(url[0], headers, url[1], None)
# Out:
# Endpoint Response Code: 200

# %%
response.keys()
# Out:
# dict_keys(['data', 'includes', 'meta'])

# %%
final_df = pd.DataFrame()

# %%
#Inputs for the request
000Z
#
#
# Endpoint Response Code: 200
# Finished fetching 50961 tweets in 4.202326059341431 seconds
# Current date: 2021-07-29T08:46:58.000Z
#
#
# Endpoint Response Code: 200
# Finished fetching 51446 tweets in 4.265597105026245 seconds
# Current date: 2021-07-28T20:58:40.000Z
#
#
# Endpoint Response Code: 200
# Finished fetching 51938 tweets in 4.418541669845581 seconds
# Current date: 2021-07-28T15:55:22.000Z
#
#
# Endpoint Response Code: 200
# Finished fetching 52420 tweets in 4.159982681274414 seconds
# Current date: 2021-07-28T11:51:43.000Z
#
#
# Endpoint Response Code: 200
# Finished fetching 52917 tweets in 4.152721166610718 seconds
# Current date: 2021-07-28T09:08:38.000Z
#
#
# Endpoint Response Code: 200
# Finished fetching 53409 tweets in 4.082826614379883 seconds
# Current date: 2021-07-27T22:09:00.000Z
#
#
# Endpoint Response Code: 200
# Finished fetching 53900 tweets in 4.542648077011108 seconds
# Current date: 2021-07-27T15:00:43.000Z
#
#
# Endpoint Response Code: 200
# Finished fetching 54388 tweets in 4.106525897979736 seconds
# Current date: 2021-07-27T09:21:19.000Z
#
#
# Endpoint Response Code: 200
# Finished fetching 54881 tweets in 4.3552610874176025 seconds
# Current date: 2021-07-26T21:50:35.000Z
#
#
# Endpoint Response Code: 200
# Finished fetching 55376 tweets in 4.174821138381958 seconds
# Current date: 2021-07-26T16:04:36.000Z
#
#
# Endpoint Response Code: 200
# Finished fetching 55870 tweets in 4.144052982330322 seconds
# Current date: 2021-07-26T08:48:03.000Z
#
#
# Endpoint Response Code: 200
# Finished fetching 56364 tweets in 4.084592819213867 seconds
# Current date: 2021-07-25T19:35:32.000Z
#
#
# Endpoint Response Code: 200
# Finished fetching 56856 tweets in 4.148989915847778 seconds
# Current date: 2021-07-25T13:14:48.000Z
#
#
# Endpoint Response Code: 200
# Finished fetching 57346 tweets in 4.127419948577881 seconds
# Current date: 2021-07-25T06:46:58.000Z
#
#
# Endpoint Response Code: 200
# Finished fetching 57831 tweets in 4.191550970077515 seconds
# Current date: 2021-07-24T11:17:31.000Z
#
#
# Endpoint Response Code: 200
# Finished fetching 58326 tweets in 4.105321168899536 seconds
# Current date: 2021-07-23T17:33:34.000Z
#
#
# Endpoint Response Code: 200
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/2530418375.py in <module>
# ----> 1 fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount=400000)
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      78
#      79
# ---> 80         fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
#      81         #bearer_token, headers, keyword, start_time, end_time, max_results,
#      82
#
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/3766073899.py in fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token)
#      51     # to not exceed api call limit per 15 minutes
#      52
# ---> 53     next_token = response["meta"]["next_token"]
#      54
#      55
#
# KeyError: 'next_token'

# %%
query2 = """(@dieLinke OR @Janine_Wissler OR  @DietmarBartsch OR #DieLinke OR #DieLINKE OR #Linke OR #dielinke OR #Bartsch OR #Wissler OR Wissler OR DieLinke)
lang:de -is:retweet 
-@cducsubt -@CDU -@ArminLaschet -#Laschet -#ArminLaschet -#laschet -#cdu -#CDU -CDU/CSU -Laschet 
-@Die_Gruenen -@ABaerbock -@GrueneBundestag -#Gruene -#Grünen -#Grüne -#GRUENEN -#AnnalenaBaerbock -#Baerbock -#baerbock -Baerbock -Grüne -Gruene
-@spdde -@OlafScholz -@spdbt -#SPD -#spd -#Spd -#Scholz -#OlafScholz -#SCHOLZ -#scholz -Scholz -SPD
-@AfD -@Alice_Weidel -@Tino_Chrupalla -#AFD -#AfD  -#afd  -#Weidel -#weidel -#Chrupalla -AFD -Weidel -Chrupalla
-@fdp -@fdpbt -@c_lindner -#FDP -#fdp -#Fdp -#Lindner -#lindner -#LINDNER -#ChristianLindner -Lindner -FDP
-#FreieWaehler -@FREIEWAEHLER_BV
-#diePARTEI -@DiePARTEI
-@Tierschutzparte -NPD -@Piratenpartei -#Piraten -#dieBasis -@diebasispartei -#Volt -@VoltDeutschland"""

# %%
query_afd = """( @AfD OR @Alice_Weidel OR @Tino_Chrupalla OR #AFD OR #AfD OR #afd OR #AlternativefürDeutschland OR #Weidel OR #weidel OR #AliceWeidel OR #WEIDEL OR #Chrupalla OR #chrupalla OR #TinoChruppala OR AFD OR Weidel OR Chrupalla)
lang:de -is:retweet
-@cducsubt -@CDU -@ArminLaschet -#Laschet -#ArminLaschet -#arminlaschet -#laschet -#cdu -#CDU -CDU/CSU -Laschet
-@Die_Gruenen -@ABaerbock -@GrueneBundestag -#Gruene -#Grünen -#Grüne -#GRUENEN -#AnnalenaBaerbock -#Baerbock -#baerbock -Baerbock -Grüne -Gruene
-@spdde -@OlafScholz -@spdbt -#SPD -#spd -#Spd -#Scholz -#OlafScholz -#SCHOLZ -#scholz -Scholz -SPD -Sozialdemokraten
-#FDP -@fdp -Lindner -@c_lindner
-#DieLinke -@dieLinke -Wissler -@Janine_Wissler -Bartsch -@DietmarBartsch
-#FreieWaehler -@FREIEWAEHLER_BV
-#diePARTEI -@DiePARTEI
-@Tierschutzparte -NPD -@Piratenpartei -#Piraten -#dieBasis -@diebasispartei -#Volt -@VoltDeutschland"""

# %%
query_fdp = """(@fdp OR @fdpbt OR @c_lindner OR #FDP OR #fdp OR #Fdp OR #Lindner OR #lindner OR #LINDNER OR #ChristianLindner OR Lindner OR FDP)
lang:de -is:retweet
-@cducsubt -@CDU -@ArminLaschet -#Laschet -#ArminLaschet -#laschet -#cdu -#CDU -CDU/CSU -Laschet
-@Die_Gruenen -@ABaerbock -@GrueneBundestag -#Gruene -#Grünen -#Grüne -#GRUENEN -#AnnalenaBaerbock -#Baerbock -#baerbock -Baerbock -Grüne -Gruene
-@spdde -@OlafScholz -@spdbt -#SPD -#spd -#Spd -#Scholz -#OlafScholz -#SCHOLZ -#scholz -Scholz -SPD
-@AfD -@Alice_Weidel -@Tino_Chrupalla -#AFD -#AfD -#afd -#Weidel -#weidel -#Chrupalla -AFD -Weidel -Chrupalla
-#DieLinke -@dieLinke -Wissler -@Janine_Wissler -Bartsch -@DietmarBartsch
-#FreieWaehler -@FREIEWAEHLER_BV
-#diePARTEI -@DiePARTEI
-@Tierschutzparte -NPD -@Piratenpartei -#Piraten -#dieBasis -@diebasispartei -#Volt -@VoltDeutschland"""

# %%
def fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token=None):
    """Calls the twitter api a maximum of tweet_amount times 
    and concats the result to a outside global defined dictionary"""
    start = time.time()
    
    
    # create url
    url = create_url(keyword, start_time, end_time, max_results)
    
    # call api
    response = connect_to_endpoint(url[0], headers, url[1], new_token)
    
    
        
    #response has 3 keys: 
    #"data": tweet information in a dict
    #"includes": dict with one key "users" which is a dict of user information
    #"meta": api request information
    
    
    # create first DataFrame out of tweet response key
    tweet_df = pd.json_normalize(response["data"])
    
    # rename columns to not get identical names with user_df
    tweet_df.rename(columns={'id':'tweet_id', 
                             'created_at': "tweet_created_at"}, 
                    inplace=True)
    
    # create second DataFrame out of user response key
    user_df = pd.json_normalize(response["includes"]["users"])
    
    # rename columns to not get identical names with tweet_df
    user_df.rename(columns={'id':'author_id',
                            'created_at': "profile_created_at"}, 
                    inplace=True)
    
    # merge two dataframes into one
    merged_df = tweet_df.merge(user_df, how = "outer", on="author_id")
    
    #sentiment = model.predict_sentiment(list(merged_df.text))
    
    #merged_df["sentiment"] = sentiment

    global final_df_others
    # concat the current search DataFrame with a result df outside of the function
    final_df_others = pd.concat([final_df_others, merged_df], ignore_index=True)
    
    
    # break if token == None --> no more results for the search query
    # otherwise call itself again this time after waiting 6 seconds 
    # to not exceed api call limit per 15 minutes
    
    next_token = response["meta"]["next_token"]
    
    
    global counter
    # increase counter by number of fetched tweets
    counter += response["meta"]["result_count"]
    
    # if too many tweets are fetched end search early to avoid exceeding tweets per month limit
    if counter > tweet_amount:
        print("Reached search limit")
        counter = 0
        return None
    
    
    if next_token:
        
        # get new token for consecutive search, returns None if search finished
        
        # sleep to not exceed api call limit
        time.sleep(3)
        
        end = time.time()
        print(f"Finished fetching {counter} tweets in {end-start} seconds")
        date = response["data"][1]["created_at"]
        print(f"Current date: {date} \n\n")
        
        
        fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
        #bearer_token, headers, keyword, start_time, end_time, max_results, 
    
    end = time.time()
    print(f"Finished fetching {counter} tweets")
    date = response["data"][1]["created_at"]
    print(f"Current date: {date} \n\n")
    print("-------Finished search-------")
    return None

# %%
"""def fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token=None):
    """Calls the twitter api a maximum of tweet_amount times 
    and concats the result to a outside global defined dictionary"""
    start = time.time()
    
    
    # create url
    url = create_url(keyword, start_time, end_time, max_results)
    
    # call api
    response = connect_to_endpoint(url[0], headers, url[1], new_token)
    
    
        
    #response has 3 keys: 
    #"data": tweet information in a dict
    #"includes": dict with one key "users" which is a dict of user information
    #"meta": api request information
    
    
    # create first DataFrame out of tweet response key
    tweet_df = pd.json_normalize(response["data"])
    
    # rename columns to not get identical names with user_df
    tweet_df.rename(columns={'id':'tweet_id', 
                             'created_at': "tweet_created_at"}, 
                    inplace=True)
    
    # create second DataFrame out of user response key
    user_df = pd.json_normalize(response["includes"]["users"])
    
    # rename columns to not get identical names with tweet_df
    user_df.rename(columns={'id':'author_id',
                            'created_at': "profile_created_at"}, 
                    inplace=True)
    
    # merge two dataframes into one
    merged_df = tweet_df.merge(user_df, how = "outer", on="author_id")
    
    #sentiment = model.predict_sentiment(list(merged_df.text))
    
    #merged_df["sentiment"] = sentiment

    global final_df_spd
    # concat the current search DataFrame with a result df outside of the function
    final_df_spd = pd.concat([final_df_spd, merged_df], ignore_index=True)
    
    
    # break if token == None --> no more results for the search query
    # otherwise call itself again this time after waiting 6 seconds 
    # to not exceed api call limit per 15 minutes
    
    next_token = response["meta"]["next_token"]
    
    
    global counter
    # increase counter by number of fetched tweets
    counter += response["meta"]["result_count"]
    
    # if too many tweets are fetched end search early to avoid exceeding tweets per month limit
    if counter > tweet_amount:
        print("Reached search limit")
        counter = 0
        return None
    
    
    if next_token:
        
        # get new token for consecutive search, returns None if search finished
        
        # sleep to not exceed api call limit
        time.sleep(3)
        
        end = time.time()
        print(f"Finished fetching {counter} tweets in {end-start} seconds")
        date = response["data"][1]["created_at"]
        print(f"Current date: {date} \n\n")
        
        
        fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
        #bearer_token, headers, keyword, start_time, end_time, max_results, 
    
    end = time.time()
    print(f"Finished fetching {counter} tweets")
    date = response["data"][1]["created_at"]
    print(f"Current date: {date} \n\n")
    print("-------Finished search-------")
    return None"""
# Out:
#   File "/var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/878245081.py", line 2
#     """Calls the twitter api a maximum of tweet_amount times
#        ^
# SyntaxError: invalid syntax

# %%
query_gruene = """( @Die_Gruenen OR @ABaerbock OR @GrueneBundestag OR #Gruene OR #Grünen OR #Grüne OR #GRUENEN OR #AnnalenaBaerbock OR #Baerbock OR #baerbock OR Baerbock OR Grüne OR Gruene)
lang:de -is:retweet
-@cducsubt -@CDU -@ArminLaschet -#Laschet -#ArminLaschet -#arminlaschet -#laschet -#cdu -#CDU -CDU/CSU -Laschet
-#SPD -@spdde -Scholz -@OlafScholz
-#AFD -@AfD -Weidel -@Alice_Weidel -Chrupalla -@Tino_Chrupalla
-#FDP -@fdp -Lindner -@c_lindner
-#DieLinke -@dieLinke -Wissler -@Janine_Wissler -Bartsch -@DietmarBartsch
-#FreieWaehler -@FREIEWAEHLER_BV
-#diePARTEI -@DiePARTEI
-@Tierschutzparte -NPD -@Piratenpartei -#Piraten -#dieBasis -@diebasispartei -#Volt -@VoltDeutschland"""

# %%
query_others = """(#FreieWaehler OR #FreieWähler OR @HubertAiwanger OR #FREIEWÄHLER OR @FREIEWAEHLER_BV #freiewähler2021 OR #diePARTEI OR @DiePARTEI OR @Tierschutzparte OR NPD OR @Piratenpartei OR #Piraten OR #dieBasis OR @diebasispartei OR #Volt OR @VoltDeutschland OR @oedp_de OR @bgepartei OR @TodenhoeferTeam OR #TeamTodenhoefer)
lang:de -is:retweet"""

# %%
query_spd = """( @spdde OR @OlafScholz OR @spdbt OR #SPD OR #spd OR #Spd OR #Scholz OR #OlafScholz OR #SCHOLZ OR #scholz OR Scholz OR SPD OR Sozialdemokraten)
lang:de -is:retweet
-@cducsubt -@CDU -@ArminLaschet -#Laschet -#ArminLaschet -#arminlaschet -#laschet -#cdu -#CDU -CDU/CSU -Laschet
-@Die_Gruenen -@ABaerbock -@GrueneBundestag -#Gruene -#Grünen -#Grüne -#GRUENEN -#AnnalenaBaerbock -#Baerbock -#baerbock -Baerbock -Grüne -Gruene
-#AFD -@AfD -Weidel -@Alice_Weidel -Chrupalla -@Tino_Chrupalla
-#FDP -@fdp -Lindner -@c_lindner
-#DieLinke -@dieLinke -Wissler -@Janine_Wissler -Bartsch -@DietmarBartsch
-#FreieWaehler -@FREIEWAEHLER_BV
-#diePARTEI -@DiePARTEI
-@Tierschutzparte -NPD -@Piratenpartei -#Piraten -#dieBasis -@diebasispartei -#Volt -@VoltDeutschland"""
