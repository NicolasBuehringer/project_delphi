# %% [markdown]
# # **API**

# %%
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time

# %%
def create_url(keyword, start_date, end_date, max_results = 10):
    
    search_url = "https://api.twitter.com/2/tweets/search/all" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': max_results,
                    'expansions': 'author_id,geo.place_id',
                    'tweet.fields': 'id,text,created_at,lang,public_metrics,source',
                    'user.fields': 'id,created_at,location,public_metrics',
                    'place.fields': 'full_name,country_code,geo,place_type',
                    'next_token': {}}
    return (search_url, query_params)

# %%
def connect_to_endpoint(url, headers, params, next_token):
    
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
query = """(@cducsubt OR @CDU OR @ArminLaschet  OR #Laschet OR #ArminLaschet  OR #arminlaschet OR #laschet OR #cdu OR #CDU OR CDU/CSU OR Laschet)
lang:de -is:retweet
-#GRUENEN -@Die_Gruenen -Baerbock -@ABaerbock
-#SPD -@spdde -Scholz -@OlafScholz
-#AFD -@AfD -Weidel -@Alice_Weidel -Chrupalla -@Tino_Chrupalla
-#FDP -@fdp -Lindner -@c_lindner
-#DieLinke -@dieLinke -Wissler -@Janine_Wissler -Bartsch -@DietmarBartsch
-#FreieWaehler -@FREIEWAEHLER_BV
-#diePARTEI -@DiePARTEI
-@Tierschutzparte -NPD -@Piratenpartei -#Piraten -#dieBasis -@diebasispartei -#Volt -@VoltDeutschland"""

# %%
url = create_url(keyword, start_time,end_time, max_results)
response = connect_to_endpoint(url[0], headers, url[1], token2)
# Out:
# Endpoint Response Code: 200

# %%
final_df = pd.DataFrame()

# %%
final_df = pd.DataFrame()

# %%
#Inputs for the request
bearer_token = os.getenv('TOKEN')
headers = {"Authorization": f"Bearer {bearer_token}"}
keyword = query_fdp
start_time = "2021-07-23T00:00:00.001Z"
end_time = "2021-08-27T00:00:00.001Z"
max_results = 500

# %%
fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount=600000)
# Out:
# Endpoint Response Code: 200
# Finished fetching 2000 tweets
# Current date: 2021-08-26
# 4.359107971191406
# Endpoint Response Code: 200
# Finished fetching 2500 tweets
# Current date: 2021-08-26
# 4.278122901916504
# Endpoint Response Code: 200
# Finished fetching 3000 tweets
# Current date: 2021-08-26
# 4.340048789978027
# Endpoint Response Code: 200
# Finished fetching 3500 tweets
# Current date: 2021-08-26
# 4.446507930755615
# Endpoint Response Code: 200
# Finished fetching 4000 tweets
# Current date: 2021-08-26
# 4.305819749832153
# Endpoint Response Code: 200
# Finished fetching 4500 tweets
# Current date: 2021-08-26
# 4.326673984527588
# Endpoint Response Code: 200
# Finished fetching 5000 tweets
# Current date: 2021-08-26
# 4.29903507232666
# Endpoint Response Code: 200
# Finished fetching 5500 tweets
# Current date: 2021-08-26
# 4.34614109992981
# Endpoint Response Code: 200
# Finished fetching 6000 tweets
# Current date: 2021-08-26
# 4.265295028686523
# Endpoint Response Code: 200
# Finished fetching 6500 tweets
# Current date: 2021-08-26
# 4.208770275115967
# Endpoint Response Code: 200
# Finished fetching 7000 tweets
# Current date: 2021-08-25
# 4.272819995880127
# Endpoint Response Code: 200
# Finished fetching 7500 tweets
# Current date: 2021-08-25
# 4.232776880264282
# Endpoint Response Code: 200
# Finished fetching 8000 tweets
# Current date: 2021-08-25
# 4.299264192581177
# Endpoint Response Code: 200
# Finished fetching 8500 tweets
# Current date: 2021-08-25
# 4.289730787277222
# Endpoint Response Code: 200
# Finished fetching 9000 tweets
# Current date: 2021-08-25
# 4.192379951477051
# Endpoint Response Code: 200
# Finished fetching 9500 tweets
# Current date: 2021-08-25
# 4.298044919967651
# Endpoint Response Code: 200
# Finished fetching 10000 tweets
# Current date: 2021-08-25
# 4.294850826263428
# Endpoint Response Code: 200
# Finished fetching 10500 tweets
# Current date: 2021-08-25
# 4.42484188079834
# Endpoint Response Code: 200
# Finished fetching 11000 tweets
# Current date: 2021-08-25
# 4.298085927963257
# Endpoint Response Code: 200
# Finished fetching 11500 tweets
# Current date: 2021-08-24
# 4.3729941844940186
# Endpoint Response Code: 200
# Finished fetching 12000 tweets
# Current date: 2021-08-24
# 4.656045913696289
# Endpoint Response Code: 200
# Finished fetching 12500 tweets
# Current date: 2021-08-24
# 4.399961233139038
# Endpoint Response Code: 200
# Finished fetching 13000 tweets
# Current date: 2021-08-24
# 4.4348790645599365
# Endpoint Response Code: 200
# Finished fetching 13500 tweets
# Current date: 2021-08-24
# 4.920691013336182
# Endpoint Response Code: 200
# Finished fetching 14000 tweets
# Current date: 2021-08-24
# 4.244059324264526
# Endpoint Response Code: 200
# Finished fetching 14500 tweets
# Current date: 2021-08-24
# 4.294573068618774
# Endpoint Response Code: 200
# Finished fetching 15000 tweets
# Current date: 2021-08-24
# 4.3913609981536865
# Endpoint Response Code: 200
# Finished fetching 15500 tweets
# Current date: 2021-08-23
# 4.287152051925659
# Endpoint Response Code: 200
# Finished fetching 16000 tweets
# Current date: 2021-08-23
# 4.233395099639893
# Endpoint Response Code: 200
# Finished fetching 16500 tweets
# Current date: 2021-08-23
# 4.347107172012329
# Endpoint Response Code: 200
# Finished fetching 17000 tweets
# Current date: 2021-08-23
# 4.248836994171143
# Endpoint Response Code: 200
# Finished fetching 17500 tweets
# Current date: 2021-08-23
# 4.256572008132935
# Endpoint Response Code: 200
# Finished fetching 18000 tweets
# Current date: 2021-08-23
# 4.349388122558594
# Endpoint Response Code: 200
# Finished fetching 18500 tweets
# Current date: 2021-08-23
# 4.290982246398926
# Endpoint Response Code: 200
# Finished fetching 19000 tweets
# Current date: 2021-08-22
# 4.437938928604126
# Endpoint Response Code: 200
# Finished fetching 19500 tweets
# Current date: 2021-08-22
# 4.2570717334747314
# Endpoint Response Code: 200
# Finished fetching 20000 tweets
# Current date: 2021-08-22
# 4.219280004501343
# Endpoint Response Code: 200
# Finished fetching 20500 tweets
# Current date: 2021-08-22
# 4.47362494468689
# Endpoint Response Code: 200
# Finished fetching 21000 tweets
# Current date: 2021-08-22
# 4.3833746910095215
# Endpoint Response Code: 200
# Finished fetching 21500 tweets
# Current date: 2021-08-22
# 4.265529155731201
# Endpoint Response Code: 200
# Finished fetching 22000 tweets
# Current date: 2021-08-22
# 4.400892972946167
# Endpoint Response Code: 200
# Finished fetching 22500 tweets
# Current date: 2021-08-22
# 4.279438734054565
# Endpoint Response Code: 200
# Finished fetching 23000 tweets
# Current date: 2021-08-21
# 4.279037952423096
# Endpoint Response Code: 200
# Finished fetching 23500 tweets
# Current date: 2021-08-21
# 4.341470956802368
# Endpoint Response Code: 200
# Finished fetching 24000 tweets
# Current date: 2021-08-21
# 4.2853899002075195
# Endpoint Response Code: 200
# Finished fetching 24500 tweets
# Current date: 2021-08-21
# 4.282703876495361
# Endpoint Response Code: 200
# Finished fetching 25000 tweets
# Current date: 2021-08-21
# 4.315423965454102
# Endpoint Response Code: 200
# Finished fetching 25500 tweets
# Current date: 2021-08-21
# 4.353160858154297
# Endpoint Response Code: 200
# Finished fetching 26000 tweets
# Current date: 2021-08-21
# 4.23730731010437
# Endpoint Response Code: 200
# Finished fetching 26500 tweets
# Current date: 2021-08-20
# 4.244335889816284
# Endpoint Response Code: 200
# Finished fetching 27000 tweets
# Current date: 2021-08-20
# 4.51965594291687
# Endpoint Response Code: 200
# Finished fetching 27500 tweets
# Current date: 2021-08-20
# 4.46396017074585
# Endpoint Response Code: 200
# Finished fetching 28000 tweets
# Current date: 2021-08-20
# 4.496624231338501
# Endpoint Response Code: 200
# Finished fetching 28500 tweets
# Current date: 2021-08-20
# 4.304841995239258
# Endpoint Response Code: 200
# Finished fetching 29000 tweets
# Current date: 2021-08-20
# 4.616831064224243
# Endpoint Response Code: 200
# Finished fetching 29500 tweets
# Current date: 2021-08-20
# 4.267715215682983
# Endpoint Response Code: 200
# Finished fetching 30000 tweets
# Current date: 2021-08-20
# 4.264493227005005
# Endpoint Response Code: 200
# Finished fetching 30500 tweets
# Current date: 2021-08-20
# 4.348404169082642
# Endpoint Response Code: 200
# Finished fetching 31000 tweets
# Current date: 2021-08-20
# 4.1836559772491455
# Endpoint Response Code: 200
# Finished fetching 31500 tweets
# Current date: 2021-08-20
# 4.289928197860718
# Endpoint Response Code: 200
# Finished fetching 32000 tweets
# Current date: 2021-08-20
# 4.24203085899353
# Endpoint Response Code: 200
# Finished fetching 32500 tweets
# Current date: 2021-08-20
# 4.251685857772827
# Endpoint Response Code: 200
# Finished fetching 33000 tweets
# Current date: 2021-08-20
# 4.345850944519043
# Endpoint Response Code: 200
# Finished fetching 33500 tweets
# Current date: 2021-08-19
# 4.2749550342559814
# Endpoint Response Code: 200
# Finished fetching 34000 tweets
# Current date: 2021-08-19
# 4.333821058273315
# Endpoint Response Code: 200
# Finished fetching 34500 tweets
# Current date: 2021-08-19
# 4.229635715484619
# Endpoint Response Code: 200
# Finished fetching 35000 tweets
# Current date: 2021-08-19
# 4.5692901611328125
# Endpoint Response Code: 200
# Finished fetching 35500 tweets
# Current date: 2021-08-19
# 4.4751057624816895
# Endpoint Response Code: 200
# Finished fetching 36000 tweets
# Current date: 2021-08-19
# 4.483547925949097
# Endpoint Response Code: 200
# Finished fetching 36500 tweets
# Current date: 2021-08-18
# 4.339603900909424
# Endpoint Response Code: 200
# Finished fetching 37000 tweets
# Current date: 2021-08-18
# 4.288949966430664
# Endpoint Response Code: 200
# Finished fetching 37500 tweets
# Current date: 2021-08-18
# 4.336178302764893
# Endpoint Response Code: 200
# Finished fetching 38000 tweets
# Current date: 2021-08-18
# 4.379213094711304
# Endpoint Response Code: 200
# Finished fetching 38500 tweets
# Current date: 2021-08-18
# 4.316133975982666
# Endpoint Response Code: 200
# Finished fetching 39000 tweets
# Current date: 2021-08-18
# 4.287613868713379
# Endpoint Response Code: 200
# Finished fetching 39500 tweets
# Current date: 2021-08-17
# 4.369125843048096
# Endpoint Response Code: 200
# Finished fetching 40000 tweets
# Current date: 2021-08-17
# 4.329897165298462
# Endpoint Response Code: 200
# Finished fetching 40500 tweets
# Current date: 2021-08-17
# 4.35408616065979
# Endpoint Response Code: 200
# Finished fetching 41000 tweets
# Current date: 2021-08-17
# 4.32141900062561
# Endpoint Response Code: 200
# Finished fetching 41500 tweets
# Current date: 2021-08-17
# 4.367534875869751
# Endpoint Response Code: 200
# Finished fetching 42000 tweets
# Current date: 2021-08-16
# 4.253627300262451
# Endpoint Response Code: 200
# Finished fetching 42500 tweets
# Current date: 2021-08-16
# 4.520161151885986
# Endpoint Response Code: 200
# Finished fetching 43000 tweets
# Current date: 2021-08-16
# 4.252481937408447
# Endpoint Response Code: 200
# Finished fetching 43500 tweets
# Current date: 2021-08-16
# 4.471886157989502
# Endpoint Response Code: 200
# Finished fetching 44000 tweets
# Current date: 2021-08-16
# 4.256526947021484
# Endpoint Response Code: 200
# Finished fetching 44500 tweets
# Current date: 2021-08-16
# 4.315381050109863
# Endpoint Response Code: 200
# Finished fetching 45000 tweets
# Current date: 2021-08-16
# 4.3852150440216064
# Endpoint Response Code: 200
# Finished fetching 45500 tweets
# Current date: 2021-08-16
# 4.424789905548096
# Endpoint Response Code: 200
# Finished fetching 46000 tweets
# Current date: 2021-08-16
# 4.3808510303497314
# Endpoint Response Code: 200
# Finished fetching 46500 tweets
# Current date: 2021-08-16
# 4.373780012130737
# Endpoint Response Code: 200
# Finished fetching 47000 tweets
# Current date: 2021-08-16
# 4.390315055847168
# Endpoint Response Code: 200
# Finished fetching 47500 tweets
# Current date: 2021-08-16
# 4.251783132553101
# Endpoint Response Code: 200
# Finished fetching 48000 tweets
# Current date: 2021-08-16
# 4.447618007659912
# Endpoint Response Code: 200
# Finished fetching 48500 tweets
# Current date: 2021-08-16
# 4.364799976348877
# Endpoint Response Code: 200
# Finished fetching 49000 tweets
# Current date: 2021-08-15
# 4.50997519493103
# Endpoint Response Code: 200
# Finished fetching 49500 tweets
# Current date: 2021-08-15
# 4.5378241539001465
# Endpoint Response Code: 200
# Finished fetching 50000 tweets
# Current date: 2021-08-15
# 4.421549081802368
# Endpoint Response Code: 200
# Finished fetching 50500 tweets
# Current date: 2021-08-15
# 4.430138111114502
# Endpoint Response Code: 200
# Finished fetching 51000 tweets
# Current date: 2021-08-15
# 4.376435279846191
# Endpoint Response Code: 200
# Finished fetching 51500 tweets
# Current date: 2021-08-15
# 4.303900241851807
# Endpoint Response Code: 200
# Finished fetching 52000 tweets
# Current date: 2021-08-15
# 4.360452175140381
# Endpoint Response Code: 200
# Finished fetching 52500 tweets
# Current date: 2021-08-15
# 4.3448498249053955
# Endpoint Response Code: 200
# Finished fetching 53000 tweets
# Current date: 2021-08-15
# 4.3269617557525635
# Endpoint Response Code: 200
# Finished fetching 53500 tweets
# Current date: 2021-08-15
# 4.474383115768433
# Endpoint Response Code: 200
# Finished fetching 54000 tweets
# Current date: 2021-08-15
# 4.408357858657837
# Endpoint Response Code: 200
# Finished fetching 54500 tweets
# Current date: 2021-08-15
# 4.399281978607178
# Endpoint Response Code: 200
# Finished fetching 55000 tweets
# Current date: 2021-08-15
# 4.534520864486694
# Endpoint Response Code: 200
# Finished fetching 55500 tweets
# Current date: 2021-08-15
# 4.449968099594116
# Endpoint Response Code: 200
# Finished fetching 56000 tweets
# Current date: 2021-08-15
# 4.528199195861816
# Endpoint Response Code: 200
# Finished fetching 56500 tweets
# Current date: 2021-08-15
# 4.314859867095947
# Endpoint Response Code: 200
# Finished fetching 57000 tweets
# Current date: 2021-08-15
# 4.328703880310059
# Endpoint Response Code: 200
# Finished fetching 57500 tweets
# Current date: 2021-08-15
# 4.312971115112305
# Endpoint Response Code: 200
# Finished fetching 58000 tweets
# Current date: 2021-08-15
# 4.84915828704834
# Endpoint Response Code: 200
# Finished fetching 58500 tweets
# Current date: 2021-08-14
# 4.465764760971069
# Endpoint Response Code: 200
# Finished fetching 59000 tweets
# Current date: 2021-08-14
# 4.359201908111572
# Endpoint Response Code: 200
# Finished fetching 59500 tweets
# Current date: 2021-08-14
# 4.32031774520874
# Endpoint Response Code: 200
# Finished fetching 60000 tweets
# Current date: 2021-08-14
# 4.387607097625732
# Endpoint Response Code: 200
# Finished fetching 60500 tweets
# Current date: 2021-08-14
# 4.512609004974365
# Endpoint Response Code: 200
# Finished fetching 61000 tweets
# Current date: 2021-08-13
# 4.797167778015137
# Endpoint Response Code: 200
# Finished fetching 61500 tweets
# Current date: 2021-08-13
# 4.744548797607422
# Endpoint Response Code: 200
# Finished fetching 62000 tweets
# Current date: 2021-08-13
# 4.576718091964722
# Endpoint Response Code: 200
# Finished fetching 62500 tweets
# Current date: 2021-08-13
# 4.296010971069336
# Endpoint Response Code: 200
# Finished fetching 63000 tweets
# Current date: 2021-08-13
# 4.446171760559082
# Endpoint Response Code: 200
# Finished fetching 63500 tweets
# Current date: 2021-08-13
# 4.367424011230469
# Endpoint Response Code: 200
# Finished fetching 64000 tweets
# Current date: 2021-08-13
# 4.385558128356934
# Endpoint Response Code: 200
# Finished fetching 64500 tweets
# Current date: 2021-08-12
# 4.325509071350098
# Endpoint Response Code: 200
# Finished fetching 65000 tweets
# Current date: 2021-08-12
# 4.306089162826538
# Endpoint Response Code: 200
# Finished fetching 65500 tweets
# Current date: 2021-08-12
# 4.5237908363342285
# Endpoint Response Code: 200
# Finished fetching 66000 tweets
# Current date: 2021-08-12
# 4.297518014907837
# Endpoint Response Code: 200
# Finished fetching 66500 tweets
# Current date: 2021-08-12
# 4.321578025817871
# Endpoint Response Code: 200
# Finished fetching 67000 tweets
# Current date: 2021-08-12
# 4.345710754394531
# Endpoint Response Code: 200
# Finished fetching 67500 tweets
# Current date: 2021-08-12
# 4.431257724761963
# Endpoint Response Code: 200
# Finished fetching 68000 tweets
# Current date: 2021-08-12
# 4.313899040222168
# Endpoint Response Code: 200
# Finished fetching 68500 tweets
# Current date: 2021-08-12
# 4.358322858810425
# Endpoint Response Code: 200
# Finished fetching 69000 tweets
# Current date: 2021-08-11
# 4.342942953109741
# Endpoint Response Code: 200
# Finished fetching 69500 tweets
# Current date: 2021-08-11
# 4.308217763900757
# Endpoint Response Code: 200
# Finished fetching 70000 tweets
# Current date: 2021-08-11
# 4.432599782943726
# Endpoint Response Code: 200
# Finished fetching 70500 tweets
# Current date: 2021-08-11
# 5.249191999435425
# Endpoint Response Code: 200
# Finished fetching 71000 tweets
# Current date: 2021-08-11
# 4.355312824249268
# Endpoint Response Code: 200
# Finished fetching 71500 tweets
# Current date: 2021-08-11
# 4.319529294967651
# Endpoint Response Code: 200
# Finished fetching 72000 tweets
# Current date: 2021-08-11
# 4.458317041397095
# Endpoint Response Code: 200
# Finished fetching 72500 tweets
# Current date: 2021-08-11
# 4.4130213260650635
# Endpoint Response Code: 200
# Finished fetching 73000 tweets
# Current date: 2021-08-11
# 4.441123008728027
# Endpoint Response Code: 200
# Finished fetching 73500 tweets
# Current date: 2021-08-11
# 4.325330972671509
# Endpoint Response Code: 200
# Finished fetching 74000 tweets
# Current date: 2021-08-11
# 4.373466730117798
# Endpoint Response Code: 200
# Finished fetching 74500 tweets
# Current date: 2021-08-11
# 4.285757780075073
# Endpoint Response Code: 200
# Finished fetching 75000 tweets
# Current date: 2021-08-11
# 4.246701955795288
# Endpoint Response Code: 200
# Finished fetching 75500 tweets
# Current date: 2021-08-11
# 4.370948791503906
# Endpoint Response Code: 200
# Finished fetching 76000 tweets
# Current date: 2021-08-11
# 4.3210368156433105
# Endpoint Response Code: 200
# Finished fetching 76500 tweets
# Current date: 2021-08-10
# 4.27171778678894
# Endpoint Response Code: 200
# Finished fetching 77000 tweets
# Current date: 2021-08-10
# 4.334309339523315
# Endpoint Response Code: 200
# Finished fetching 77500 tweets
# Current date: 2021-08-10
# 4.300384998321533
# Endpoint Response Code: 200
# Finished fetching 78000 tweets
# Current date: 2021-08-10
# 4.271219968795776
# Endpoint Response Code: 200
# Finished fetching 78500 tweets
# Current date: 2021-08-10
# 4.686332941055298
# Endpoint Response Code: 200
# Finished fetching 79000 tweets
# Current date: 2021-08-10
# 4.339576959609985
# Endpoint Response Code: 200
# Finished fetching 79500 tweets
# Current date: 2021-08-10
# 4.252223014831543
# Endpoint Response Code: 200
# Finished fetching 80000 tweets
# Current date: 2021-08-10
# 4.370377063751221
# Endpoint Response Code: 200
# Finished fetching 80500 tweets
# Current date: 2021-08-10
# 4.439477205276489
# Endpoint Response Code: 200
# Finished fetching 81000 tweets
# Current date: 2021-08-10
# 4.407379865646362
# Endpoint Response Code: 200
# Finished fetching 81500 tweets
# Current date: 2021-08-10
# 4.307816028594971
# Endpoint Response Code: 200
# Finished fetching 82000 tweets
# Current date: 2021-08-10
# 4.424793720245361
# Endpoint Response Code: 200
# Finished fetching 82500 tweets
# Current date: 2021-08-09
# 4.4828410148620605
# Endpoint Response Code: 200
# Finished fetching 83000 tweets
# Current date: 2021-08-09
# 4.316478967666626
# Endpoint Response Code: 200
# Finished fetching 83500 tweets
# Current date: 2021-08-09
# 4.598219871520996
# Endpoint Response Code: 200
# Finished fetching 84000 tweets
# Current date: 2021-08-09
# 4.372070074081421
# Endpoint Response Code: 200
# Finished fetching 84500 tweets
# Current date: 2021-08-09
# 4.725616931915283
# Endpoint Response Code: 200
# Finished fetching 85000 tweets
# Current date: 2021-08-09
# 4.518896102905273
# Endpoint Response Code: 200
# Finished fetching 85500 tweets
# Current date: 2021-08-09
# 4.371365070343018
# Endpoint Response Code: 200
# Finished fetching 86000 tweets
# Current date: 2021-08-09
# 4.284926891326904
# Endpoint Response Code: 200
# Finished fetching 86500 tweets
# Current date: 2021-08-08
# 4.30871319770813
# Endpoint Response Code: 200
# Finished fetching 87000 tweets
# Current date: 2021-08-08
# 4.336321115493774
# Endpoint Response Code: 200
# Finished fetching 87500 tweets
# Current date: 2021-08-08
# 4.301011800765991
# Endpoint Response Code: 200
# Finished fetching 88000 tweets
# Current date: 2021-08-08
# 4.349809885025024
# Endpoint Response Code: 200
# Finished fetching 88500 tweets
# Current date: 2021-08-08
# 4.348285913467407
# Endpoint Response Code: 200
# Finished fetching 89000 tweets
# Current date: 2021-08-08
# 4.342099905014038
# Endpoint Response Code: 200
# Finished fetching 89500 tweets
# Current date: 2021-08-07
# 4.295583963394165
# Endpoint Response Code: 200
# Finished fetching 90000 tweets
# Current date: 2021-08-07
# 4.315464019775391
# Endpoint Response Code: 200
# Finished fetching 90500 tweets
# Current date: 2021-08-07
# 4.995151996612549
# Endpoint Response Code: 200
# Finished fetching 91000 tweets
# Current date: 2021-08-07
# 4.59906005859375
# Endpoint Response Code: 200
# Finished fetching 91500 tweets
# Current date: 2021-08-07
# 4.6680567264556885
# Endpoint Response Code: 200
# Finished fetching 92000 tweets
# Current date: 2021-08-06
# 4.362078905105591
# Endpoint Response Code: 200
# Finished fetching 92500 tweets
# Current date: 2021-08-06
# 4.468379735946655
# Endpoint Response Code: 200
# Finished fetching 93000 tweets
# Current date: 2021-08-06
# 4.431450843811035
# Endpoint Response Code: 200
# Finished fetching 93500 tweets
# Current date: 2021-08-06
# 4.557011842727661
# Endpoint Response Code: 200
# Finished fetching 94000 tweets
# Current date: 2021-08-06
# 4.560294151306152
# Endpoint Response Code: 200
# Finished fetching 94500 tweets
# Current date: 2021-08-06
# 4.335326194763184
# Endpoint Response Code: 200
# Finished fetching 95000 tweets
# Current date: 2021-08-05
# 5.470988035202026
# Endpoint Response Code: 200
# Finished fetching 95500 tweets
# Current date: 2021-08-05
# 4.748701095581055
# Endpoint Response Code: 200
# Finished fetching 96000 tweets
# Current date: 2021-08-05
# 4.472325801849365
# Endpoint Response Code: 200
# Finished fetching 96500 tweets
# Current date: 2021-08-05
# 4.3194420337677
# Endpoint Response Code: 200
# Finished fetching 97000 tweets
# Current date: 2021-08-05
# 4.939420938491821
# Endpoint Response Code: 200
# Finished fetching 97500 tweets
# Current date: 2021-08-05
# 4.408845901489258
# Endpoint Response Code: 200
# Finished fetching 98000 tweets
# Current date: 2021-08-05
# 4.304718732833862
# Endpoint Response Code: 200
# Finished fetching 98500 tweets
# Current date: 2021-08-05
# 4.590826034545898
# Endpoint Response Code: 200
# Finished fetching 99000 tweets
# Current date: 2021-08-05
# 4.641862869262695
# Endpoint Response Code: 200
# Finished fetching 99500 tweets
# Current date: 2021-08-05
# 4.3418190479278564
# Endpoint Response Code: 200
# Finished fetching 100000 tweets
# Current date: 2021-08-04
# 4.732115030288696
# Endpoint Response Code: 200
# Finished fetching 100500 tweets
# Current date: 2021-08-04
# 4.4574620723724365
# Endpoint Response Code: 200
# Finished fetching 101000 tweets
# Current date: 2021-08-04
# 4.322023868560791
# Endpoint Response Code: 200
# Finished fetching 101500 tweets
# Current date: 2021-08-04
# 4.393603086471558
# Endpoint Response Code: 200
# Finished fetching 102000 tweets
# Current date: 2021-08-04
# 4.555032730102539
# Endpoint Response Code: 200
# Finished fetching 102500 tweets
# Current date: 2021-08-04
# 4.33549427986145
# Endpoint Response Code: 200
# Finished fetching 103000 tweets
# Current date: 2021-08-04
# 4.556185245513916
# Endpoint Response Code: 200
# Finished fetching 103500 tweets
# Current date: 2021-08-04
# 4.438333988189697
# Endpoint Response Code: 200
# Finished fetching 104000 tweets
# Current date: 2021-08-04
# 4.659400224685669
# Endpoint Response Code: 200
# Finished fetching 104500 tweets
# Current date: 2021-08-03
# 4.730317831039429
# Endpoint Response Code: 200
# Finished fetching 105000 tweets
# Current date: 2021-08-03
# 4.598863124847412
# Endpoint Response Code: 200
# Finished fetching 105500 tweets
# Current date: 2021-08-03
# 4.491453170776367
# Endpoint Response Code: 200
# Finished fetching 106000 tweets
# Current date: 2021-08-03
# 4.416804790496826
# Endpoint Response Code: 200
# Finished fetching 106500 tweets
# Current date: 2021-08-03
# 4.318311929702759
# Endpoint Response Code: 200
# Finished fetching 107000 tweets
# Current date: 2021-08-03
# 4.600224018096924
# Endpoint Response Code: 200
# Finished fetching 107500 tweets
# Current date: 2021-08-03
# 4.542686939239502
# Endpoint Response Code: 200
# Finished fetching 108000 tweets
# Current date: 2021-08-03
# 4.361832141876221
# Endpoint Response Code: 200
# Finished fetching 108500 tweets
# Current date: 2021-08-02
# 4.739696979522705
# Endpoint Response Code: 200
# Finished fetching 109000 tweets
# Current date: 2021-08-02
# 4.745399236679077
# Endpoint Response Code: 200
# Finished fetching 109500 tweets
# Current date: 2021-08-02
# 4.754183053970337
# Endpoint Response Code: 200
# Finished fetching 110000 tweets
# Current date: 2021-08-02
# 4.684591054916382
# Endpoint Response Code: 200
# Finished fetching 110500 tweets
# Current date: 2021-08-02
# 5.012620687484741
# Endpoint Response Code: 200
# Finished fetching 111000 tweets
# Current date: 2021-08-02
# 4.947172164916992
# Endpoint Response Code: 200
# Finished fetching 111500 tweets
# Current date: 2021-08-02
# 4.575874090194702
# Endpoint Response Code: 200
# Finished fetching 112000 tweets
# Current date: 2021-08-01
# 4.456682920455933
# Endpoint Response Code: 200
# Finished fetching 112500 tweets
# Current date: 2021-08-01
# 4.56130313873291
# Endpoint Response Code: 200
# Finished fetching 113000 tweets
# Current date: 2021-08-01
# 4.719560861587524
# Endpoint Response Code: 200
# Finished fetching 113500 tweets
# Current date: 2021-08-01
# 4.760942220687866
# Endpoint Response Code: 200
# Finished fetching 114000 tweets
# Current date: 2021-08-01
# 4.663217782974243
# Endpoint Response Code: 200
# Finished fetching 114500 tweets
# Current date: 2021-08-01
# 4.365290880203247
# Endpoint Response Code: 200
# Finished fetching 115000 tweets
# Current date: 2021-08-01
# 4.511036157608032
# Endpoint Response Code: 200
# Finished fetching 115500 tweets
# Current date: 2021-07-31
# 4.592982053756714
# Endpoint Response Code: 200
# Finished fetching 116000 tweets
# Current date: 2021-07-31
# 4.297253131866455
# Endpoint Response Code: 200
# Finished fetching 116500 tweets
# Current date: 2021-07-31
# 4.740394115447998
# Endpoint Response Code: 200
# Finished fetching 117000 tweets
# Current date: 2021-07-30
# 4.554461717605591
# Endpoint Response Code: 200
# Finished fetching 117500 tweets
# Current date: 2021-07-30
# 4.470702171325684
# Endpoint Response Code: 200
# Finished fetching 118000 tweets
# Current date: 2021-07-30
# 4.6022889614105225
# Endpoint Response Code: 200
# Finished fetching 118500 tweets
# Current date: 2021-07-30
# 4.630698919296265
# Endpoint Response Code: 200
# Finished fetching 119000 tweets
# Current date: 2021-07-30
# 4.4839019775390625
# Endpoint Response Code: 200
# Finished fetching 119500 tweets
# Current date: 2021-07-29
# 4.505146026611328
# Endpoint Response Code: 200
# Finished fetching 120000 tweets
# Current date: 2021-07-29
# 4.526639223098755
# Endpoint Response Code: 200
# Finished fetching 120500 tweets
# Current date: 2021-07-29
# 4.3335840702056885
# Endpoint Response Code: 200
# Finished fetching 121000 tweets
# Current date: 2021-07-29
# 4.4340550899505615
# Endpoint Response Code: 200
# Finished fetching 121500 tweets
# Current date: 2021-07-29
# 4.52156400680542
# Endpoint Response Code: 200
# Finished fetching 122000 tweets
# Current date: 2021-07-28
# 4.45317816734314
# Endpoint Response Code: 200
# Finished fetching 122500 tweets
# Current date: 2021-07-28
# 4.532049179077148
# Endpoint Response Code: 200
# Finished fetching 123000 tweets
# Current date: 2021-07-28
# 4.617429971694946
# Endpoint Response Code: 200
# Finished fetching 123500 tweets
# Current date: 2021-07-28
# 4.439543008804321
# Endpoint Response Code: 200
# Finished fetching 124000 tweets
# Current date: 2021-07-28
# 4.7043540477752686
# Endpoint Response Code: 200
# Finished fetching 124500 tweets
# Current date: 2021-07-28
# 4.638986825942993
# Endpoint Response Code: 200
# Finished fetching 125000 tweets
# Current date: 2021-07-28
# 4.462251901626587
# Endpoint Response Code: 200
# Finished fetching 125500 tweets
# Current date: 2021-07-27
# 4.377858877182007
# Endpoint Response Code: 200
# Finished fetching 126000 tweets
# Current date: 2021-07-27
# 4.629470109939575
# Endpoint Response Code: 200
# Finished fetching 126500 tweets
# Current date: 2021-07-27
# 4.367044925689697
# Endpoint Response Code: 200
# Finished fetching 127000 tweets
# Current date: 2021-07-27
# 4.598509073257446
# Endpoint Response Code: 200
# Finished fetching 127500 tweets
# Current date: 2021-07-27
# 4.713542938232422
# Endpoint Response Code: 200
# Finished fetching 128000 tweets
# Current date: 2021-07-27
# 4.433369159698486
# Endpoint Response Code: 200
# Finished fetching 128500 tweets
# Current date: 2021-07-27
# 5.1914989948272705
# Endpoint Response Code: 200
# Finished fetching 129000 tweets
# Current date: 2021-07-26
# 4.561821222305298
# Endpoint Response Code: 200
# Finished fetching 129500 tweets
# Current date: 2021-07-26
# 4.6573779582977295
# Endpoint Response Code: 200
# Finished fetching 130000 tweets
# Current date: 2021-07-26
# 4.734889984130859
# Endpoint Response Code: 200
# Finished fetching 130500 tweets
# Current date: 2021-07-26
# 4.326918125152588
# Endpoint Response Code: 200
# Finished fetching 131000 tweets
# Current date: 2021-07-26
# 4.338146924972534
# Endpoint Response Code: 200
# Finished fetching 131500 tweets
# Current date: 2021-07-26
# 4.359488010406494
# Endpoint Response Code: 200
# Finished fetching 132000 tweets
# Current date: 2021-07-26
# 4.484877824783325
# Endpoint Response Code: 200
# Finished fetching 132500 tweets
# Current date: 2021-07-26
# 4.430168151855469
# Endpoint Response Code: 200
# Finished fetching 133000 tweets
# Current date: 2021-07-26
# 4.4213738441467285
# Endpoint Response Code: 200
# Finished fetching 133500 tweets
# Current date: 2021-07-26
# 4.377709150314331
# Endpoint Response Code: 200
# Finished fetching 134000 tweets
# Current date: 2021-07-26
# 4.492581129074097
# Endpoint Response Code: 200
# Finished fetching 134500 tweets
# Current date: 2021-07-26
# 4.42850399017334
# Endpoint Response Code: 200
# Finished fetching 135000 tweets
# Current date: 2021-07-26
# 4.390379190444946
# Endpoint Response Code: 200
# Finished fetching 135500 tweets
# Current date: 2021-07-26
# 4.303391933441162
# Endpoint Response Code: 200
# Finished fetching 136000 tweets
# Current date: 2021-07-25
# 4.302552938461304
# Endpoint Response Code: 200
# Finished fetching 136500 tweets
# Current date: 2021-07-25
# 4.4011781215667725
# Endpoint Response Code: 200
# Finished fetching 137000 tweets
# Current date: 2021-07-25
# 4.424566030502319
# Endpoint Response Code: 200
# Finished fetching 137500 tweets
# Current date: 2021-07-25
# 4.297578811645508
# Endpoint Response Code: 200
# Finished fetching 138000 tweets
# Current date: 2021-07-25
# 4.345503091812134
# Endpoint Response Code: 200
# Finished fetching 138500 tweets
# Current date: 2021-07-25
# 4.35673713684082
# Endpoint Response Code: 200
# Finished fetching 139000 tweets
# Current date: 2021-07-25
# 4.408252716064453
# Endpoint Response Code: 200
# Finished fetching 139500 tweets
# Current date: 2021-07-25
# 4.308302879333496
# Endpoint Response Code: 200
# Finished fetching 140000 tweets
# Current date: 2021-07-25
# 4.412628889083862
# Endpoint Response Code: 200
# Finished fetching 140500 tweets
# Current date: 2021-07-25
# 4.3833558559417725
# Endpoint Response Code: 200
# Finished fetching 141000 tweets
# Current date: 2021-07-25
# 4.35632586479187
# Endpoint Response Code: 200
# Finished fetching 141500 tweets
# Current date: 2021-07-25
# 4.3768510818481445
# Endpoint Response Code: 200
# Finished fetching 142000 tweets
# Current date: 2021-07-25
# 4.701896905899048
# Endpoint Response Code: 200
# Finished fetching 142500 tweets
# Current date: 2021-07-25
# 4.472309589385986
# Endpoint Response Code: 200
# Finished fetching 143000 tweets
# Current date: 2021-07-25
# 4.317225217819214
# Endpoint Response Code: 200
# Finished fetching 143500 tweets
# Current date: 2021-07-25
# 4.301794767379761
# Endpoint Response Code: 200
# Finished fetching 144000 tweets
# Current date: 2021-07-24
# 4.39298677444458
# Endpoint Response Code: 200
# Finished fetching 144500 tweets
# Current date: 2021-07-24
# 4.2310731410980225
# Endpoint Response Code: 200
# Finished fetching 145000 tweets
# Current date: 2021-07-24
# 4.3265061378479
# Endpoint Response Code: 200
# Finished fetching 145500 tweets
# Current date: 2021-07-24
# 4.530308246612549
# Endpoint Response Code: 200
# Finished fetching 146000 tweets
# Current date: 2021-07-24
# 4.316236972808838
# Endpoint Response Code: 200
# Finished fetching 146500 tweets
# Current date: 2021-07-24
# 4.380207061767578
# Endpoint Response Code: 200
# Finished fetching 147000 tweets
# Current date: 2021-07-24
# 4.407185792922974
# Endpoint Response Code: 200
# Finished fetching 147500 tweets
# Current date: 2021-07-23
# 4.334235191345215
# Endpoint Response Code: 200
# Finished fetching 148000 tweets
# Current date: 2021-07-23
# 4.2597572803497314
# Endpoint Response Code: 200
# Finished fetching 148500 tweets
# Current date: 2021-07-23
# 4.353325128555298
# Endpoint Response Code: 200
# Finished fetching 149000 tweets
# Current date: 2021-07-23
# 4.320487976074219
# Endpoint Response Code: 200

# %%
final_df_fdp = pd.DataFrame()

# %%
final_df_fdp.to_csv("total_fdp.csv", index=False)

# %%
pd.read_csv("total_fdp.csv")
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_92927/2450465476.py in <module>
# ----> 1 pd.read_csv("total_fdp.csv")
#
# ~/.pyenv/versions/3.8.6/envs/project_delphi/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.pyenv/versions/3.8.6/envs/project_delphi/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/.pyenv/versions/3.8.6/envs/project_delphi/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/.pyenv/versions/3.8.6/envs/project_delphi/lib/python3.8/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/.pyenv/versions/3.8.6/envs/project_delphi/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/.pyenv/versions/3.8.6/envs/project_delphi/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      67         kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
#      68         try:
# ---> 69             self._reader = parsers.TextReader(self.handles.handle, **kwds)
#      70         except Exception:
#      71             self.handles.close()
#
# ~/.pyenv/versions/3.8.6/envs/project_delphi/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %%
counter = 0

# %%
query2 = """(@dieLinke OR @Janine_Wissler OR  @DietmarBartsch OR #DieLinke OR #DieLINKE OR #Linke OR #dielinke OR #Bartsch OR #Wissler OR Wissler OR DieLinke)
lang:de -is:retweet 
-@cducsubt -@CDU -@ArminLaschet -#Laschet -#ArminLaschet -#laschet -#cdu -#CDU -CDU/CSU -Laschet 
-@Die_Gruenen -@ABaerbock -@GrueneBundestag -#Gruene -#Grünen -#Grüne -#GRUENEN -#AnnalenaBaerbock -#Baerbock -#baerbock -Baerbock -Grüne -Gruene
-@spdde -@OlafScholz -@spdbt -#SPD -#spd -#Spd -#Scholz -#OlafScholz -#SCHOLZ -#scholz -Scholz -SPD
-@AfD -@Alice_Weidel -@Tino_Chrupalla -#AFD -#AfD  -#afd  -#Weidel -#weidel -#Chrupalla -AFD -Weidel -Chrupalla
-@fdp -@fdpbt -@c_lindner -#FDP -#fdp -#Fdp -#Lindner -#lindner -#LINDNER -#ChristianLindner -Lindner -FDP
-#FreieWaehler -@FREIEWAEHLER_BV
-#diePARTEI -@DiePARTEI
-@Tierschutzparte -NPD -@Piratenpartei -#Piraten -#dieBasis -@diebasispartei -#Volt -@VoltDeutschland"""

# %%
query_fdp = """(@fdp OR @fdpbt OR @c_lindner OR #FDP OR #fdp OR #Fdp OR #Lindner OR #lindner OR #LINDNER OR #ChristianLindner OR Lindner OR FDP)
lang:de -is:retweet
-@cducsubt -@CDU -@ArminLaschet -#Laschet -#ArminLaschet -#laschet -#cdu -#CDU -CDU/CSU -Laschet
-@Die_Gruenen -@ABaerbock -@GrueneBundestag -#Gruene -#Grünen -#Grüne -#GRUENEN -#AnnalenaBaerbock -#Baerbock -#baerbock -Baerbock -Grüne -Gruene
-@spdde -@OlafScholz -@spdbt -#SPD -#spd -#Spd -#Scholz -#OlafScholz -#SCHOLZ -#scholz -Scholz -SPD
-@AfD -@Alice_Weidel -@Tino_Chrupalla -#AFD -#AfD -#afd -#Weidel -#weidel -#Chrupalla -AFD -Weidel -Chrupalla
-#DieLinke -@dieLinke -Wissler -@Janine_Wissler -Bartsch -@DietmarBartsch
-#FreieWaehler -@FREIEWAEHLER_BV
-#diePARTEI -@DiePARTEI
-@Tierschutzparte -NPD -@Piratenpartei -#Piraten -#dieBasis -@diebasispartei -#Volt -@VoltDeutschland"""

# %%
def fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, new_token=None):
    
    start = time.time()
    
    
    global counter
    # increase counter by number of fetched tweets
    counter += max_results
    
    # if too many tweets are fetched end search early to avoid exceeding tweets per month limit
    if counter > tweet_amount:
        print("Reached search limit")
        counter = 0
        return None
    
    # create url
    url = create_url(keyword, start_time, end_time, max_results)
    
    # call api
    response = connect_to_endpoint(url[0], headers, url[1], new_token)
    
    
        
    #response has 3 keys: 
    #"data": tweet information in a dict
    #"includes": dict with one key "users" which is a dict of user information
    #"meta": api request information
    
    
    
    # create first DataFrame out of tweet response key
    tweet_df = pd.json_normalize(response["data"])
    
    # rename columns to not get identical names with user_df
    tweet_df.rename(columns={'id':'tweet_id', 
                             'created_at': "tweet_created_at"}, 
                    inplace=True)
    
    # create second DataFrame out of user response key
    user_df = pd.json_normalize(response["includes"]["users"])
    
    # rename columns to not get identical names with tweet_df
    user_df.rename(columns={'id':'author_id',
                            'created_at': "profile_created_at"}, 
                    inplace=True)
    
    # merge two dataframes into one
    merged_df = tweet_df.merge(user_df, how = "outer", on="author_id")
    
    #sentiment = model.predict_sentiment(list(merged_df.text))
    
    #merged_df["sentiment"] = sentiment

    global final_df_union
    # concat the current search DataFrame with a result df outside of the function
    final_df_union = pd.concat([final_df_union, merged_df], ignore_index=True)
    
    
    # break if token == None --> no more results for the search query
    # otherwise call itself again this time after waiting 6 seconds 
    # to not exceed api call limit per 15 minutes
    if response["meta"].get("next_token", None):
        
        # get new token for consecutive search, returns None if search finished
        next_token = response["meta"]["next_token"]
        # sleep to not exceed api call limit
        time.sleep(2)
        
        end = time.time()
        print(f"Finished fetching {counter} tweets")
        date = response["data"][1]["created_at"][:10]
        print(f"Current date: {date} \n\n")
        print(end - start)
        
        fetch_tweets(headers, keyword, start_time, end_time, max_results, tweet_amount, next_token)
        #bearer_token, headers, keyword, start_time, end_time, max_results, 
    
    end = time.time()
    print(f"Finished fetching {counter} tweets")
    date = response["data"][1]["created_at"][:10]
    print(f"Current date: {date} \n\n")
    print("-------Finished search-------")
    return None

# %%
raus = ["username", "name", "tweet_count", "listed_count", "author_id"]

# %%
response["data"][1]["created_at"][:10]
# Out:
# '2021-08-24'
