# %%
# !ls
# Out:
# afd.ipynb                     nicolas_twitter_scraper.ipynb
# afd_real.csv                  spd.csv
# fdp.csv                       spd.ipynb
# gruene.csv                    union.csv
# gruene_linke.ipynb            union.ipynb
# linke.csv

# %%
pd.read_csv("union.csv")
# Out:
# /Users/nicolas/.pyenv/versions/3.8.6/envs/project_delphi/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                          id      conversation_id                created_at  \
# 0       1429940439797403649  1429124309323296774  2021-08-24 00:55:42 CEST
# 1       1429940112847167489  1428244201322471424  2021-08-24 00:54:24 CEST
# 2       1429940049156661252  1429914911895863296  2021-08-24 00:54:09 CEST
# 3       1429939893069885440  1429818153459195911  2021-08-24 00:53:32 CEST
# 4       1429939749054304265  1429914911895863296  2021-08-24 00:52:57 CEST
# ...                     ...                  ...                       ...
# 128227  1426952593998233600  1426815664401047553  2021-08-15 19:03:04 CEST
# 128228  1426952582312902659  1426944319647330315  2021-08-15 19:03:01 CEST
# ...

# %%
# !rm afd_bis_08_16.csv

# %%
import twint
import nest_asyncio
import pandas as pd

query = "@AfDimBundestag OR @afdimbundestag OR @AfD OR @afd OR @Alice_Weidel OR @alice_weidel OR @Tino_Chrupalla OR @tino_chrupalla OR #Chrupalla OR #chrupalla OR #Weidel OR #weidel OR #AfD OR #afd"

nest_asyncio.apply()
#configuration
config = twint.Config()
config.Search = query
config.Lang = "de"
config.Since = "2021-07-01"
config.Until = "2021-08-14"
config.Store_csv = True
config.Output = "afd_bis_08_16.csv"
#running search
twint.run.Search(config)
# Out:
# 1426332716140744708 2021-08-14 01:59:54 +0200 <Atomreisfleisch> @pirandot @aegidius @fandorinmusic Die #AfD ist doch am Ende. Mit der würde ich mich gar nicht mehr so aufhalten.
# 1426332690828103685 2021-08-14 01:59:48 +0200 <nippongames> @Emma_nzipiert @Schinkmeister @TIDE_HH @AfD Man sollte eh mit den Taliban und auch mit Assad verhandeln, damit sie ihre Bevölkerung zurücknehmen. Die Realität auszublenden bringt gar nichts, die Afghanen hätten es selbst in der Hand gehabt die Taliban abzuwehren, aber jede Stadt fällt ohne große Gegenwehr bisher.
# 1426332401454747648 2021-08-14 01:58:39 +0200 <Tokata01> @nachthell @Volksverpetzer @AfD RechtschreibAlternative für Deutschland! #RafD xD
# 1426331972960391168 2021-08-14 01:56:56 +0200 <dalax82> @NettiRobert @diehappy_77 @Tino_Chrupalla @ToniKroos Die Grammatikpolizei verwarnt Sie!
# ...

# %%
pd.read_csv("linke.csv")
# Out:
#                         id      conversation_id                created_at  \
# 0       910654498208649216   910421209887715328  2017-09-21 01:58:46 CEST
# 1       910649814135820288   910545776270565377  2017-09-21 01:40:09 CEST
# 2       910645769237012480   910516662910173184  2017-09-21 01:24:05 CEST
# 3       910642033181827072   910545776270565377  2017-09-21 01:09:14 CEST
# 4       910640192486338560   910583781962190851  2017-09-21 01:01:55 CEST
# ...                    ...                  ...                       ...
# 14624  1426953413032620033  1426660953559547916  2021-08-15 19:06:19 CEST
# 14625  1426953300763680769  1426800886739787783  2021-08-15 19:05:53 CEST
# 14626  1426953225933045764  1426948300209598466  2021-08-15 19:05:35 CEST
# 14627  1426953180500348930  1426953180500348930  2021-08-15 19:05:24 CEST
# 14628  1426953172933877760  1426948300209598466  2021-08-15 19:05:22 CEST
#
#              date      time  timezone              user_id         username  \
# ...
