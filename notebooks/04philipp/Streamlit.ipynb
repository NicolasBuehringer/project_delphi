# %%
import pandas as pd
import numpy as np

# %%
historic_polls = pd.read_csv("../../raw_data/polls.csv")

# %%
#test df
np.random.seed(2021)
N = 10
rng = pd.date_range(start='2021-08-16', end='2021-08-25')
df = pd.DataFrame(np.random.uniform(5, 20, size=(10,14)), columns=["CSU", "SPD", "Grünen", "FDP", "Linken", "AFD", "Others", "CSU_poll", "SPD_poll", "Grünen_poll", "FDP_poll", "Linken_poll", "AFD_poll", "Others_poll"], index=rng)
df.plot()
# Out:
# <AxesSubplot:>

# %%
historic_polls.drop(columns=["Unnamed: 0", "Surveyed_Persons"], inplace=True)

# %%
# Out:
#           Date    SPD  CDU/CSU  Grüne    FDP    AfD  Linke  other
# 0   2021-05-26  15.33    25.67  23.33  12.83  10.50   6.17   6.17
# 1   2021-05-27  15.00    26.00  22.00  12.00  11.00   7.00   7.00
# 2   2021-05-28  14.00    25.00  23.00  11.50  12.50   8.00   6.00
# 3   2021-05-29  16.00    25.00  22.00  13.00  12.00   7.00   5.00
# 4   2021-05-30  15.75    25.25  21.75  13.25  11.50   6.75   5.75
# ..         ...    ...      ...    ...    ...    ...    ...    ...
# 91  2021-08-25  21.50    22.50  17.50  12.50  12.00   7.00   7.50
# 92  2021-08-26  23.00    23.00  18.00  12.00  11.00   7.00   6.00
# 93  2021-08-27  23.00    22.00  18.00  11.50  11.00   7.00   8.00
# 94  2021-08-28  24.00    23.50  17.00  11.75  10.75   6.00   7.00
# 95  2021-08-29  24.50    21.75  16.75  12.62  10.88   6.50   7.00
#
# [96 rows x 8 columns]

# %%
historic_polls.set_index("Date")
# Out:
#               SPD  CDU/CSU  Grüne    FDP    AfD  Linke  other
# Date
# 2021-05-26  15.33    25.67  23.33  12.83  10.50   6.17   6.17
# 2021-05-27  15.00    26.00  22.00  12.00  11.00   7.00   7.00
# 2021-05-28  14.00    25.00  23.00  11.50  12.50   8.00   6.00
# 2021-05-29  16.00    25.00  22.00  13.00  12.00   7.00   5.00
# 2021-05-30  15.75    25.25  21.75  13.25  11.50   6.75   5.75
# ...           ...      ...    ...    ...    ...    ...    ...
# 2021-08-25  21.50    22.50  17.50  12.50  12.00   7.00   7.50
# 2021-08-26  23.00    23.00  18.00  12.00  11.00   7.00   6.00
# 2021-08-27  23.00    22.00  18.00  11.50  11.00   7.00   8.00
# 2021-08-28  24.00    23.50  17.00  11.75  10.75   6.00   7.00
# 2021-08-29  24.50    21.75  16.75  12.62  10.88   6.50   7.00
#
# [96 rows x 7 columns]

# %%
historic_polls.dtypes
# Out:
# Date        object
# SPD        float64
# CDU/CSU    float64
# Grüne      float64
# FDP        float64
# AfD        float64
# Linke      float64
# other      float64
# dtype: object

# %%
alle = pd.read_csv("../../raw_data/df_all_v2.csv")

# %%
alle.head()
# Out:
#    Unnamed: 0 party           tweet_date     author_id      tweet_id  \
# 0           0   CDU  2021-08-26 23:59:59  2.025364e+07  1.431044e+18
# 1           1   CDU  2021-08-26 23:56:43  4.715415e+09  1.431043e+18
# 2           2   CDU  2021-08-26 23:55:40  3.214661e+09  1.431043e+18
# 3           3   CDU  2021-08-26 23:54:03  9.239238e+08  1.431042e+18
# 4           4   CDU  2021-08-26 23:53:42  1.381014e+18  1.431042e+18
#
#                                                 text               source  \
# 0  @Graf_Fencheltee @Darbales1 Hab mich mal zwisc...      Twitter Web App
# 1  @phoenix_de @Inselkind16 @KayGottschalk1 @AfDi...  Twitter for Android
# 2  @_FriedrichMerz Ich übersetze mal kurz: „lasch...   Twitter for iPhone
# 3  #Flüchtlinge #Politik Laschet nennt Ende der R...              dlvr.it
# 4  @peteraltmaier @cducsubt Und wofür war die Bun...      Twitter Web App
#
#           username  retweet_count  reply_count  like_count  \
# 0      MSchimanski            0.0          0.0         3.0
# 1    YachtSkipper2            0.0          0.0         0.0
# 2        QuakBoing            0.0          0.0         2.0
# 3  Rekonquista1492            0.0          0.0         0.0
# 4  1K4tMqqn0KLzpVw            0.0          0.0         0.0
#
#   profile_creation_date  followers_count  following_count  user_tweet_count  \
# 0   2009-02-06 17:27:25            419.0           1035.0           18082.0
# 1   2016-01-05 14:26:34            171.0             31.0            6111.0
# 2   2015-04-27 20:47:08             40.0            384.0            3369.0
# 3   2012-11-03 19:52:01            206.0             88.0          138251.0
# 4   2021-04-10 22:40:34              2.0             13.0             467.0
#
#       location  sentiment
# 0  Deutschland         -2
# 1          NaN          1
# 2          NaN         -2
# 3          NaN          1
# 4          NaN         -2
